# %% [markdown]
# ## Nama : Naila Zulfa Nabila
# ## Jalur Pembelajaran : Data Analyst & AI

# %%
# import library
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as pltip

# %%
pip install xlrd==2.0.1
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# import dataset
df = pd.read_excel("US Superstore data.xls")
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %% [markdown]
# - Terdapat jumlah kolom sebanyak 21 dan baris sebanyak 9994 <br>
# - Tidak terdapat nilai null pada semua kolom

# %%
df.describe()
# Out:
#             Row ID                     Order Date  \
# count  9994.000000                           9994
# mean   4997.500000  2016-04-30 00:07:12.259355648
# min       1.000000            2014-01-03 00:00:00
# 25%    2499.250000            2015-05-23 00:00:00
# 50%    4997.500000            2016-06-26 00:00:00
# 75%    7495.750000            2017-05-14 00:00:00
# max    9994.000000            2017-12-30 00:00:00
# std    2885.163629                            NaN
#
#                            Ship Date   Postal Code         Sales     Quantity  \
# count                           9994   9994.000000   9994.000000  9994.000000
# mean   2016-05-03 23:06:58.571142912  55190.379428    229.858001     3.789574
# min              2014-01-07 00:00:00   1040.000000      0.444000     1.000000
# 25%              2015-05-27 00:00:00  23223.000000     17.280000     2.000000
# 50%              2016-06-29 00:00:00  56430.500000     54.490000     3.000000
# ...

# %% [markdown]
# - Rata-rata nilai penjualan dari seluruh transaksi adalah 229,86 satuan mata uang tertentu. Namun, median hanya sebesar 54,49. Perbedaan signifikan antara mean dan median mengindikasikan adanya distribusi skewed ke kanan, di mana beberapa transaksi dengan nilai penjualan sangat tinggi (seperti maksimum 22.638,48) memengaruhi rata-rata.
# - Rata-rata jumlah barang yang dibeli dalam satu transaksi adalah 3,79 unit, sementara median adalah 3 unit. Nilai mean yang mendekati median menunjukkan bahwa distribusi jumlah barang per transaksi relatif simetris, tanpa adanya outlier signifikan yang memengaruhi distribusi.
# - Rata-rata diskon yang diberikan dalam transaksi adalah 15,62%, dengan median sebesar 20%. Perbedaan yang kecil antara mean dan median mengindikasikan distribusi diskon yang mendekati simetris, sehingga sebagian besar transaksi menerima diskon dalam rentang yang tidak terlalu bervariasi.
# - Rata-rata keuntungan per transaksi adalah sekitar 28,66. Namun, median keuntungan hanya sebesar 8,67. Perbedaan yang besar antara mean dan median menunjukkan adanya transaksi dengan keuntungan yang sangat besar, tetapi juga transaksi dengan kerugian besar (seperti maksimum 8399.976000), sehingga distribusinya skewed ke kanan.

# %%
num = ['Row ID', 'Postal Code', 'Sales', 'Quantity', 'Discount', 'Profit']
cat = ['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Region', 'Category', 'Sub-Category']

# Melakukan analisis deskriptif untuk kolom-kolom kategorikal
df[cat].describe()
# Out:
#              Ship Mode   Segment        Country           City       State  \
# count             9994      9994           9994           9994        9994
# unique               4         3              1            531          49
# top     Standard Class  Consumer  United States  New York City  California
# freq              5968      5191           9994            915        2001
#
#        Region         Category Sub-Category
# count    9994             9994         9994
# unique      4                3           17
# top      West  Office Supplies      Binders
# freq     3203             6026         1523

# %% [markdown]
# - Data menunjukkan bahwa dari empat jenis moda pengiriman, Standard Class paling umum digunakan dengan 5.968 transaksi.
# - Terdapat tiga segmen pelanggan, di mana Consumer mendominasi dengan 5.191 transaksi.
# - Seluruh transaksi berasal dari United States, mencakup 531 kota, dengan New York City memiliki transaksi terbanyak (915 transaksi), serta 49 negara bagian, di mana California mencatat transaksi terbanyak (2.001 transaksi).
# - Dari empat wilayah yang ada, West memiliki transaksi terbanyak (3.203 transaksi).
# - Dalam kategori produk, Office Supplies mendominasi dengan 6.026 transaksi dari total tiga kategori yang tersedia, sementara sub-kategori Binders menjadi yang paling populer di antara 17 sub-kategori, dengan 1.523 transaksi.

# %%
df['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %% [markdown]
# - Data terkait Ship Mode menunjukkan bahwa moda pengiriman Standard Class merupakan pilihan utama dengan 5.968 transaksi yang iikuti oleh Second Class dengan 1.945 transaksi, First Class dengan 1.538 transaksi, dan Same Day sebagai moda pengiriman yang paling jarang digunakan, hanya sebanyak 543 transaksi.
# - Mengindikasikan preferensi pelanggan terhadap pengiriman lebih menyukai pengiriman ekonomis, daripada pengiriman yang lebih cepat seperti Same Day.

# %% [markdown]
# ## ANALISIS UNIVARIATE

# %%
# Boxplot
features = num
for i in range(0, len(features)):
    plt.subplot(1, len(features), i+1)
    sns.boxplot(y=df[features[i]], color='green', orient='v')
    plt.tight_layout()

# %% [markdown]
# - Terdapat outlier pada variabel Sales, Quantity, Discount, dan Profit

# %%
#displot
feature = num
plt.figure(figsize=(15, 8))
for i in range(0, len(feature)):
    plt.subplot(2,4, i+1)
    sns.kdeplot(x=df[feature[i]], color='green')
    plt.xlabel(feature[i])
    plt.tight_layout()

# %% [markdown]
# - Row ID menunjukkan distribusi yang merata, mengindikasikan bahwa data ini adalah pengidentifikasi unik tanpa pola tertentu.
# - Postal Code memiliki beberapa puncak, menandakan keberadaan kode pos tertentu yang mendominasi data.
# - Sales menunjukkan distribusi yang sangat condong ke kiri (right-skewed) dengan sebagian besar nilai berada di kisaran rendah tetapi ada beberapa nilai yang sangat tinggi.
# - Quantity memiliki distribusi yang tidak merata dengan sebagian besar transaksi mencatat kuantitas kecil dan sedikit yang mencatat kuantitas besar.
# - Discount menunjukkan dua puncak yang menonjol di dekat nol dan nilai diskon yang umum digunakan.
# - Profit menunjukkan distribusi yang simetris dengan puncak di sekitar nol, mengindikasikan bahwa sebagian besar transaksi memiliki keuntungan kecil atau nol, dengan beberapa mengalami kerugian besar atau keuntungan besar.

# %%
#violin plot
featuress= num
for i in range (0, len(featuress)):
    plt.subplot(1,len(featuress), i+1)
    sns.violinplot(y=df[featuress[i]], color='gray', orient='v')
    plt.tight_layout()

# %% [markdown]
# Sama dengan penjelasan Bloxplot

# %%
#countplot 
features = cat
plt.figure(figsize=(len(features) * 5, 5))

for i in range(0, len(features)):
    plt.subplot(1, len(features), i+1)
    sns.countplot(x=df[features[i]], color='green')
    plt.xticks(rotation=45) 
    plt.tight_layout()

plt.show()

# %% [markdown]
# - Pada Ship Mode, sebagian besar menggunakan pengiriman Standard Class dengan sisanya menggunakan Second Claa, First Class, dan Same Day.
# - Pada Segment didominasi oleh Consumer yang kemudian diikuti oleh Corporate dan Home Office.
# - Pada Country, semua berasal dari United State.
# - Pada City, distribusi jumlah per kota sangat bervariasi dengan beberapa kota memiliki jumlah transaksi yang tinggi.
# - Pada State, distribusi jumlah per negara bagian sangat bervariasi dengan negara bagian tertentu mendominasi, seperti California.
# - Pada Region, Wilayah West dan East mendominasi sementara South dan Centrak memiliki transaksi lebih sedikit.
# - Pada Category didominasi oleh kategori Office Supplies yang kemudian diikuti oleh Furniture dan Technology.
# - Pada Sub-Category, distribusi jumlah per per sub-kategori sangat bervariasi dengan didominasi seperti Binders dan Paper.

# %% [markdown]
# ## ANALISIS MULTIVARIATE

# %%
df[num].corr()
# Out:
#                Row ID  Postal Code     Sales  Quantity  Discount    Profit
# Row ID       1.000000     0.009671 -0.001359 -0.004016  0.013480  0.012497
# Postal Code  0.009671     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales       -0.001359    -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity    -0.004016     0.012761  0.200795  1.000000  0.008623  0.066253
# Discount     0.013480     0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit       0.012497    -0.029961  0.479064  0.066253 -0.219487  1.000000

# %% [markdown]
# - Row ID: Tidak memiliki korelasi kuat dengan variabel lain, menunjukkan bahwa ini hanya atribut identitas.
# - Postal Code: Tidak memiliki korelasi signifikan dengan variabel lain.
# - Sales: Memiliki korelasi sedang dengan Profit (0.479) yang menunjukkan bahwa penjualan yang tinggi berhubungan terhadap keuntungan lebih besar.
# - Quantity: Memiliki korelasi sedikit dengan Sales (0.201) menunjukkan bahwa jumlah pembelian berhubungan dengan nilai penjualan.
# - Discount: Memiliki korelasi negatif sedang dengan Profit (-0.219), menunjukkan bahwa diskon yang tinggi dapat mengurangi keuntungan.
# - Profit: Dipengaruhi positif oleh Sales (0.479) dan negatif oleh Discount (-0.219).

# %%
# correlation heatmap
plt.figure(figsize=(8, 8))
sns.heatmap(df[num].corr(), cmap='Blues', annot=True, fmt='.2f')
# Out:
# <Axes: >

# %%
#pairplot
plt.figure(figsize=(15, 15))
sns.pairplot(df, diag_kind='kde')

# %% [markdown]
# - Sales vs. Profit: Penjualan yang tinggi cenderung menghasilkan keuntungan yang besar (Berkorelasi positif)
# - Quantity vs. Sales: Peningkatan kuantitas sedikit memengaruhi nilai penjualan (Berkorelasi positif).
# - Discount vs. Profit: Diskon tinggi seringkali terkait dengan keuntungan yang lebih rendah (Berkorelasi negatif).
